# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r'C:\Users\user\OneDrive\Desktop\Data Science\Student-Performance-Prediction-System\csv\Student_Performance.csv')

# %%
df
# Out:
#        student_id  age  gender school_type parent_education  study_hours  \
# 0               1   14    male      public    post graduate          3.1
# 1               2   18  female      public         graduate          3.7
# 2               3   17  female     private    post graduate          7.9
# 3               4   16   other      public      high school          1.1
# 4               5   16  female      public      high school          1.3
# ...           ...  ...     ...         ...              ...          ...
# 24995       12047   17  female      public              phd          1.8
# 24996        1102   16  female     private          diploma          2.7
# 24997        4422   19   other     private    post graduate          1.0
# 24998        7858   14    male     private          diploma          1.0
# 24999       11621   18   other      public        no formal          0.7
#
#        attendance_percentage internet_access travel_time extra_activities  \
# ...

# %%
df.isna().sum()
# Out:
# student_id               0
# age                      0
# gender                   0
# school_type              0
# parent_education         0
# study_hours              0
# attendance_percentage    0
# internet_access          0
# travel_time              0
# extra_activities         0
# study_method             0
# math_score               0
# science_score            0
# english_score            0
# overall_score            0
# final_grade              0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(10000)

# %%
df.drop_duplicates()
# Out:
#        student_id  age  gender school_type parent_education  study_hours  \
# 0               1   14    male      public    post graduate          3.1
# 1               2   18  female      public         graduate          3.7
# 2               3   17  female     private    post graduate          7.9
# 3               4   16   other      public      high school          1.1
# 4               5   16  female      public      high school          1.3
# ...           ...  ...     ...         ...              ...          ...
# 14995       14996   17    male     private         graduate          1.8
# 14996       14997   17   other     private          diploma          6.7
# 14997       14998   17    male     private              phd          5.2
# 14998       14999   16   other     private         graduate          1.0
# 14999       15000   14   other      public        no formal          0.9
#
#        attendance_percentage internet_access travel_time extra_activities  \
# ...

# %%
df.drop(['math_score','science_score','english_score','student_id','final_grade'],axis=1,inplace=True)

# %%
df
# Out:
#        age  gender school_type parent_education  study_hours  \
# 0       14    male      public    post graduate          3.1
# 1       18  female      public         graduate          3.7
# 2       17  female     private    post graduate          7.9
# 3       16   other      public      high school          1.1
# 4       16  female      public      high school          1.3
# ...    ...     ...         ...              ...          ...
# 24995   17  female      public              phd          1.8
# 24996   16  female     private          diploma          2.7
# 24997   19   other     private    post graduate          1.0
# 24998   14    male     private          diploma          1.0
# 24999   18   other      public        no formal          0.7
#
#        attendance_percentage internet_access travel_time extra_activities  \
# 0                       84.3             yes     <15 min              yes
# 1                       87.8             yes     >60 min               no
# ...

# %%
df['gender'].unique()
# Out:
# <StringArray>
# ['male', 'female', 'other']
# Length: 3, dtype: str

# %%
gender_dict = { 'male':0,'female':1,'other':2}
df['gender'] = df['gender'].map(gender_dict)

# %%
df
# Out:
#        age  gender school_type parent_education  study_hours  \
# 0       14       0      public    post graduate          3.1
# 1       18       1      public         graduate          3.7
# 2       17       1     private    post graduate          7.9
# 3       16       2      public      high school          1.1
# 4       16       1      public      high school          1.3
# ...    ...     ...         ...              ...          ...
# 24995   17       1      public              phd          1.8
# 24996   16       1     private          diploma          2.7
# 24997   19       2     private    post graduate          1.0
# 24998   14       0     private          diploma          1.0
# 24999   18       2      public        no formal          0.7
#
#        attendance_percentage internet_access travel_time extra_activities  \
# 0                       84.3             yes     <15 min              yes
# 1                       87.8             yes     >60 min               no
# ...

# %%
df['school_type'].unique()
# Out:
# <StringArray>
# ['public', 'private']
# Length: 2, dtype: str

# %%
school_dict = {'public':0, 'private':1}
df['school_type'] = df['school_type'].map(school_dict)

# %%
df
# Out:
#        age  gender  school_type parent_education  study_hours  \
# 0       14       0            0    post graduate          3.1
# 1       18       1            0         graduate          3.7
# 2       17       1            1    post graduate          7.9
# 3       16       2            0      high school          1.1
# 4       16       1            0      high school          1.3
# ...    ...     ...          ...              ...          ...
# 24995   17       1            0              phd          1.8
# 24996   16       1            1          diploma          2.7
# 24997   19       2            1    post graduate          1.0
# 24998   14       0            1          diploma          1.0
# 24999   18       2            0        no formal          0.7
#
#        attendance_percentage internet_access travel_time extra_activities  \
# 0                       84.3             yes     <15 min              yes
# ...

# %%
df['parent_education'].unique()
# Out:
# <StringArray>
# ['post graduate', 'graduate', 'high school', 'no formal', 'diploma', 'phd']
# Length: 6, dtype: str

# %%
parent_dict = {'post graduate':0, 'graduate':1, 'high school':2, 'no formal':3, 'diploma':4, 'phd':5}
df['parent_education'] = df['parent_education'].map(parent_dict)

# %%
df
# Out:
#        age  gender  school_type  parent_education  study_hours  \
# 0       14       0            0                 0          3.1
# 1       18       1            0                 1          3.7
# 2       17       1            1                 0          7.9
# 3       16       2            0                 2          1.1
# 4       16       1            0                 2          1.3
# ...    ...     ...          ...               ...          ...
# 24995   17       1            0                 5          1.8
# 24996   16       1            1                 4          2.7
# 24997   19       2            1                 0          1.0
# 24998   14       0            1                 4          1.0
# 24999   18       2            0                 3          0.7
#
#        attendance_percentage internet_access travel_time extra_activities  \
# 0                       84.3             yes     <15 min              yes
# ...

# %%
internet_dict = {'yes':0,'no':1}
df['internet_access'] = df['internet_access'].map(internet_dict)

# %%
df
# Out:
#        age  gender  school_type  parent_education  study_hours  \
# 0       14       0            0                 0          3.1
# 1       18       1            0                 1          3.7
# 2       17       1            1                 0          7.9
# 3       16       2            0                 2          1.1
# 4       16       1            0                 2          1.3
# ...    ...     ...          ...               ...          ...
# 24995   17       1            0                 5          1.8
# 24996   16       1            1                 4          2.7
# 24997   19       2            1                 0          1.0
# 24998   14       0            1                 4          1.0
# 24999   18       2            0                 3          0.7
#
#        attendance_percentage  internet_access travel_time extra_activities  \
# 0                       84.3                0     <15 min              yes
# ...

# %%
df['travel_time'].unique()
# Out:
# <StringArray>
# ['<15 min', '>60 min', '15-30 min', '30-60 min']
# Length: 4, dtype: str

# %%
travel_dict = {'<15 min':0, '>60 min':1, '15-30 min':2, '30-60 min':3}
df['travel_time'] = df['travel_time'].map(travel_dict)

# %%
df
# Out:
#        age  gender  school_type  parent_education  study_hours  \
# 0       14       0            0                 0          3.1
# 1       18       1            0                 1          3.7
# 2       17       1            1                 0          7.9
# 3       16       2            0                 2          1.1
# 4       16       1            0                 2          1.3
# ...    ...     ...          ...               ...          ...
# 24995   17       1            0                 5          1.8
# 24996   16       1            1                 4          2.7
# 24997   19       2            1                 0          1.0
# 24998   14       0            1                 4          1.0
# 24999   18       2            0                 3          0.7
#
#        attendance_percentage  internet_access  travel_time extra_activities  \
# 0                       84.3                0            0              yes
# ...

# %%
extra_activity_dict = {'yes':0,'no':1}
df['extra_activities'] = df['extra_activities'].map(extra_activity_dict)

# %%
df
# Out:
#        age  gender  school_type  parent_education  study_hours  \
# 0       14       0            0                 0          3.1
# 1       18       1            0                 1          3.7
# 2       17       1            1                 0          7.9
# 3       16       2            0                 2          1.1
# 4       16       1            0                 2          1.3
# ...    ...     ...          ...               ...          ...
# 24995   17       1            0                 5          1.8
# 24996   16       1            1                 4          2.7
# 24997   19       2            1                 0          1.0
# 24998   14       0            1                 4          1.0
# 24999   18       2            0                 3          0.7
#
#        attendance_percentage  internet_access  travel_time  extra_activities  \
# 0                       84.3                0            0                 0
# ...

# %%
df['study_method'].unique()
# Out:
# <StringArray>
# ['notes', 'textbook', 'group study', 'coaching', 'mixed', 'online videos']
# Length: 6, dtype: str

# %%
study_method_dict = {'notes':0, 'textbook':1, 'group study':2, 'coaching':3, 'mixed':4, 'online videos':5}
df['study_method'] = df['study_method'].map(study_method_dict)

# %%
df
# Out:
#        age  gender  school_type  parent_education  study_hours  \
# 0       14       0            0                 0          3.1
# 1       18       1            0                 1          3.7
# 2       17       1            1                 0          7.9
# 3       16       2            0                 2          1.1
# 4       16       1            0                 2          1.3
# ...    ...     ...          ...               ...          ...
# 24995   17       1            0                 5          1.8
# 24996   16       1            1                 4          2.7
# 24997   19       2            1                 0          1.0
# 24998   14       0            1                 4          1.0
# 24999   18       2            0                 3          0.7
#
#        attendance_percentage  internet_access  travel_time  extra_activities  \
# 0                       84.3                0            0                 0
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 25000 entries, 0 to 24999
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   age                    25000 non-null  int64
#  1   gender                 25000 non-null  int64
#  2   school_type            25000 non-null  int64
#  3   parent_education       25000 non-null  int64
#  4   study_hours            25000 non-null  float64
#  5   attendance_percentage  25000 non-null  float64
#  6   internet_access        25000 non-null  int64
#  7   travel_time            25000 non-null  int64
#  8   extra_activities       25000 non-null  int64
#  9   study_method           25000 non-null  int64
#  10  overall_score          25000 non-null  float64
# dtypes: float64(3), int64(8)
# memory usage: 2.1 MB

# %%
df.to_csv('Cleaned_student.csv')
